# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.read_csv('../data/permeability/bbbp_pampa.csv')
df.head()
# Out:
#                                               SMILES  Y
# 0                   CC(C)NCC(O)COc1cccc2ccccc12.[Cl]  1
# 1             CC(C)(C)OC(=O)CCCc1ccc(N(CCCl)CCCl)cc1  1
# 2   CC1COc2c(N3CCN(C)CC3)c(F)cc3c(=O)c(C(=O)O)cn1c23  1
# 3                     CC(=O)NCCCOc1cccc(CN2CCCCC2)c1  1
# 4  Cc1onc(-c2ccccc2Cl)c1C(=O)N[C@@H]1C(=O)N2[C@@H...  1

# %%
counts = df['Y'].value_counts()
plot_df = pd.DataFrame({'Y': counts.index, 'count': counts.values})
sns.set_style(style="white")
sns.set_context("talk")
plot_df = pd.DataFrame(df['Y'].value_counts)
sns.barplot(data=plot_df, x='Y', y='count', palette='viridis')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_388243/3653107114.py in ?()
#       1 counts = df['Y'].value_counts()
#       2 plot_df = pd.DataFrame({'Y': counts.index, 'count': counts.values})
#       3 sns.set_style(style="white")
#       4 sns.set_context("talk")
# ----> 5 plot_df = pd.DataFrame(df['Y'].value_counts)
#       6 sns.barplot(data=plot_df, x='Y', y='count', palette='viridis')
#
# ~/miniconda3/envs/chemprop/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, data, index, columns, dtype, copy)
#     882                 )
#     883         # For data is scalar
#     884         else:
#     885             if index is None or columns is None:
# --> 886                 raise ValueError("DataFrame constructor not properly called!")
#     887
#     888             index = ensure_index(index)
# ...

# %%
from src.featurizer import MordredFeaturizer
from src.predictor.scikit import RfClassifier

model = RfClassifier(target_metric='roc_auc')

# %%
featurizer = MordredFeaturizer()
model.inject_featurizer(featurizer)

model

# %%
model.save('../test.pkl')

# %%
model_reloaded = RfClassifier(target_metric='roc_auc')
model_reloaded.load('../test.pkl')

# %%
model.featurizer
